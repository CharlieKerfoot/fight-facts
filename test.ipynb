# %%
import pandas as pd
db = pd.read_csv('temp.csv')

# %%
total_fights_mul = 0.2
recency_mul = 0.2
title_fights_mul = 0.2
win_loss_ratio_mul = 0.2

db["popularity"] = db["total_fights"]*total_fights_mul
db
# Out:
#       first_name   last_name       nickname  wins  losses  draws  height  \
# 0          Colby  Thicknesse      Slickness     7       1      0   5' 7"
# 1        Rongzhu         NaN            NaN    26       6      0   5' 9"
# 2       Jonathan    Micallef    The Captain     8       1      0   6' 0"
# 3        Quillan    Salkilld            NaN     8       1      0   6' 0"
# 4         Bogdan        Grad  The Unleashed    15       2      0   5' 8"
# ...          ...         ...            ...   ...     ...    ...     ...
# 2597  Melquizael       Costa    Melk Cauthy    22       7      0  5' 10"
# 2598      Victor       Henry    La Mangosta    24       7      0   5' 7"
# 2599     Charlie   Brenneman   The Spaniard    19       8      0  5' 10"
# 2600      Wagner      Campos         Galeto    12      10      0   5' 6"
# 2601     Marcelo        Rojo        Pitbull    16      10      0   5' 8"
#
#         weight reach    stance    birth_date    last_fight_date  total_fights  \
# ...
